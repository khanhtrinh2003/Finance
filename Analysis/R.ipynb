# %%
library(ggplot2)
library(plotly)

# %%
df<-read.csv("goog.csv")

# %%
a <- lm(data=df, Close~t1+t2+t3)

# %%
df$predic <- predict(a)

# %%
hist(a$residuals,breaks=50)
# Out:
# Plot with title "Histogram of a$residuals"
